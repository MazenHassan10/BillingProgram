# %% [markdown]
# # All Cases

# %%
import pandas as pd

#make a data frame from Transactions - All Cases Report.csv
AllCases = pd.read_csv('../DataBase/Transactions - All Cases Report.csv')

# %%
AllCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                413 non-null    object
#  1   Last Name                 413 non-null    object
#  2   Service Type              413 non-null    object
#  3   Location Name             413 non-null    object
#  4   Physcian Name             413 non-null    object
#  5   Date of Service           413 non-null    object
#  6   Date Billed               413 non-null    object
#  7   Full Service Description  413 non-null    object
#  8   Law Firm                  413 non-null    object
#  9   Attorney                  413 non-null    object
#  10  Case Rep                  404 non-null    object
#  11  Item Charge               413 non-null    int64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
AllCases['Case Rep'] = AllCases['Case Rep'].fillna('unknown')
AllCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                413 non-null    object
#  1   Last Name                 413 non-null    object
#  2   Service Type              413 non-null    object
#  3   Location Name             413 non-null    object
#  4   Physcian Name             413 non-null    object
#  5   Date of Service           413 non-null    object
#  6   Date Billed               413 non-null    object
#  7   Full Service Description  413 non-null    object
#  8   Law Firm                  413 non-null    object
#  9   Attorney                  413 non-null    object
#  10  Case Rep                  413 non-null    object
#  11  Item Charge               413 non-null    int64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
# fill missings in "Paid Amount" with 0
AllCases['Paid Amount'] = AllCases['Paid Amount'].fillna(0)
AllCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                413 non-null    object
#  1   Last Name                 413 non-null    object
#  2   Service Type              413 non-null    object
#  3   Location Name             413 non-null    object
#  4   Physcian Name             413 non-null    object
#  5   Date of Service           413 non-null    object
#  6   Date Billed               413 non-null    object
#  7   Full Service Description  413 non-null    object
#  8   Law Firm                  413 non-null    object
#  9   Attorney                  413 non-null    object
#  10  Case Rep                  413 non-null    object
#  11  Item Charge               413 non-null    int64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
#fill discount amount missings with 0
AllCases['Discount Amount'] = AllCases['Discount Amount'].fillna(0)
AllCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                413 non-null    object
#  1   Last Name                 413 non-null    object
#  2   Service Type              413 non-null    object
#  3   Location Name             413 non-null    object
#  4   Physcian Name             413 non-null    object
#  5   Date of Service           413 non-null    object
#  6   Date Billed               413 non-null    object
#  7   Full Service Description  413 non-null    object
#  8   Law Firm                  413 non-null    object
#  9   Attorney                  413 non-null    object
#  10  Case Rep                  413 non-null    object
#  11  Item Charge               413 non-null    int64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
#make date of service, date billed, payment date, settlement date, discount date columns datetime type and if empty put NaT
date_columns = ['Date of Service', 'Date Billed', 'Pmt Date', 'Discount Date']
for col in date_columns:
    AllCases[col] = pd.to_datetime(AllCases[col], errors='coerce').dt.strftime("%m-%d-%Y")
AllCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                413 non-null    object
#  1   Last Name                 413 non-null    object
#  2   Service Type              413 non-null    object
#  3   Location Name             413 non-null    object
#  4   Physcian Name             413 non-null    object
#  5   Date of Service           413 non-null    object
#  6   Date Billed               413 non-null    object
#  7   Full Service Description  413 non-null    object
#  8   Law Firm                  413 non-null    object
#  9   Attorney                  413 non-null    object
#  10  Case Rep                  413 non-null    object
#  11  Item Charge               413 non-null    int64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
def clean_percentage(value):
    # Remove $ sign, commas, and % symbol, then convert to float
    return float(value.replace("$", "").replace(",", "").replace("%", "").strip())
    #apply function to Collection and Lien columns
AllCases['Collection %'] = AllCases['Collection %'].apply(clean_percentage)
AllCases['Lien Reduction %'] = AllCases['Lien Reduction %'].apply(clean_percentage)
AllCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                413 non-null    object
#  1   Last Name                 413 non-null    object
#  2   Service Type              413 non-null    object
#  3   Location Name             413 non-null    object
#  4   Physcian Name             413 non-null    object
#  5   Date of Service           413 non-null    object
#  6   Date Billed               413 non-null    object
#  7   Full Service Description  413 non-null    object
#  8   Law Firm                  413 non-null    object
#  9   Attorney                  413 non-null    object
#  10  Case Rep                  413 non-null    object
#  11  Item Charge               413 non-null    int64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
AllCases.head()
# Out:
#   First Name Last Name  Service Type       Location Name      Physcian Name  \
# 0     Sharaf       Ali  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 1   Melaynie     Armas  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 2    Ignacio      Diaz  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 3      Mitra   Atabaki  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 4    Ernesto     Borja  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
#
#   Date of Service Date Billed Full Service Description  \
# 0      04-12-2024  04-18-2024     Initial Consultation
# 1      03-29-2024  04-09-2024     Initial Consultation
# 2      06-21-2024  06-27-2024     Initial Consultation
# 3      07-26-2024  07-31-2024     Initial Consultation
# 4      11-22-2024  11-26-2024     Initial Consultation
#
#                                Law Firm                 Attorney  \
# 0      Law Office of Young and  Nichols      Michael Young, Esq.
# ...

# %%
#fill missings in "Discount Date" and "Pmt Date" with NaT
AllCases['Discount Date'] = AllCases['Discount Date'].fillna(pd.NaT)
AllCases['Pmt Date'] = AllCases['Pmt Date'].fillna(pd.NaT)
AllCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                413 non-null    object
#  1   Last Name                 413 non-null    object
#  2   Service Type              413 non-null    object
#  3   Location Name             413 non-null    object
#  4   Physcian Name             413 non-null    object
#  5   Date of Service           413 non-null    object
#  6   Date Billed               413 non-null    object
#  7   Full Service Description  413 non-null    object
#  8   Law Firm                  413 non-null    object
#  9   Attorney                  413 non-null    object
#  10  Case Rep                  413 non-null    object
#  11  Item Charge               413 non-null    int64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
AllCases.head()
# Out:
#   First Name Last Name  Service Type       Location Name      Physcian Name  \
# 0     Sharaf       Ali  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 1   Melaynie     Armas  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 2    Ignacio      Diaz  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 3      Mitra   Atabaki  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 4    Ernesto     Borja  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
#
#   Date of Service Date Billed Full Service Description  \
# 0      04-12-2024  04-18-2024     Initial Consultation
# 1      03-29-2024  04-09-2024     Initial Consultation
# 2      06-21-2024  06-27-2024     Initial Consultation
# 3      07-26-2024  07-31-2024     Initial Consultation
# 4      11-22-2024  11-26-2024     Initial Consultation
#
#                                Law Firm                 Attorney  \
# 0      Law Office of Young and  Nichols      Michael Young, Esq.
# ...

# %% [markdown]
# # Open Cases

# %%
# make a data frame from  Transactions - Open Case AR Report.csv
OpenCases = pd.read_csv('../DataBase/Transactions - Open Case AR Report.csv')
OpenCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                427 non-null    object
#  1   Last Name                 427 non-null    object
#  2   Service Type              427 non-null    object
#  3   Physcian Name             427 non-null    object
#  4   Date of Service           427 non-null    object
#  5   Location Name             427 non-null    object
#  6   Date Billed               427 non-null    object
#  7   Service Provided          427 non-null    object
#  8   Full Service Description  427 non-null    object
#  9   Law Firm                  427 non-null    object
#  10  Attorney                  427 non-null    object
#  11  Case Rep                  416 non-null    object
#  12  Item Charge               427 non-null    int64
# ...

# %%
OpenCases[OpenCases['First Name'] == 'Veronica']
# Out:
#     First Name Last Name  Service Type      Physcian Name Date of Service  \
# 154   Veronica   Marquez  Professional  Philip Khoury, DO       2/28/2025
# 264   Veronica   Marquez      Facility  Philip Khoury, DO        6/7/2025
# 265   Veronica   Marquez    Anesthesia    Preet Patel, MD        6/7/2025
# 271   Veronica   Marquez  Professional  Philip Khoury, DO        6/7/2025
# 312   Veronica   Marquez  Professional  Philip Khoury, DO       7/11/2025
# 354   Veronica   Marquez  Professional  Philip Khoury, DO        8/8/2025
# 381   Veronica   Marquez  Professional  Philip Khoury, DO       8/23/2025
# 404   Veronica   Marquez    Anesthesia    Preet Patel, MD       8/23/2025
# 412   Veronica   Marquez  Professional  Philip Khoury, DO        9/5/2025
# 424   Veronica   Marquez      Facility  Philip Khoury, DO       8/23/2025
#
#                                          Location Name Date Billed  \
# 154                                 SCOPES HEALTH INC.    3/3/2025
# ...

# %%
print(OpenCases['Pmt Date'].values)
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
# ...

# %%
# make date of service, date billed and Pmt Date and Discount Date columns datetime type and if empty put NaT
date_columns = ['Date of Service', 'Date Billed', 'Discount Date']
for col in date_columns:
    OpenCases[col] = pd.to_datetime(OpenCases[col], errors='coerce').dt.strftime("%m-%d-%Y")
OpenCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                427 non-null    object
#  1   Last Name                 427 non-null    object
#  2   Service Type              427 non-null    object
#  3   Physcian Name             427 non-null    object
#  4   Date of Service           427 non-null    object
#  5   Location Name             427 non-null    object
#  6   Date Billed               427 non-null    object
#  7   Service Provided          427 non-null    object
#  8   Full Service Description  427 non-null    object
#  9   Law Firm                  427 non-null    object
#  10  Attorney                  427 non-null    object
#  11  Case Rep                  416 non-null    object
#  12  Item Charge               427 non-null    int64
# ...

# %%
OpenCases.head()
# Out:
#   First Name Last Name  Service Type      Physcian Name Date of Service  \
# 0    Katrina     Costa  Professional  Philip Khoury, DO      02-09-2024
# 1     Denise    Norris  Professional  Philip Khoury, DO      02-16-2024
# 2    Katrina     Costa  Professional  Philip Khoury, DO      02-24-2024
# 3    Katrina     Costa  Professional  Philip Khoury, DO      03-15-2024
# 4     Ismael    Patino  Professional  Philip Khoury, DO      04-05-2024
#
#         Location Name Date Billed      Service Provided  \
# 0  SCOPES HEALTH INC.  04-23-2024  Initial Consultation
# 1  SCOPES HEALTH INC.  02-21-2024  Initial Consultation
# 2  SCOPES HEALTH INC.  04-30-2024   Injection Procedure
# 3  SCOPES HEALTH INC.  05-14-2024             Follow up
# 4  SCOPES HEALTH INC.  04-10-2024  Initial Consultation
#
#    Full Service Description                          Law Firm  \
# 0      Initial Consultation  Law Office of Young and  Nichols
# 1      Initial Consultation                 Drake Legal Group
# ...

# %%
def clean_percentage(value):
    # Remove $ sign, commas, and % symbol, then convert to float
    try:
        # If it's already a number, return it
        if isinstance(value, (int, float)):
            return float(value)
        # If it's a string, clean it and convert
        return float(str(value).replace("$", "").replace(",", "").replace("%", "").strip())
    except (ValueError, AttributeError):
        # Return None for any values that can't be converted
        return None

#apply function to Collection and Lien columns
OpenCases['Collection %'] = OpenCases['Collection %'].apply(clean_percentage)
OpenCases['Lien Reduction %'] = OpenCases['Lien Reduction %'].apply(clean_percentage)
OpenCases.head()
# Out:
#   First Name Last Name  Service Type      Physcian Name Date of Service  \
# 0    Katrina     Costa  Professional  Philip Khoury, DO      02-09-2024
# 1     Denise    Norris  Professional  Philip Khoury, DO      02-16-2024
# 2    Katrina     Costa  Professional  Philip Khoury, DO      02-24-2024
# 3    Katrina     Costa  Professional  Philip Khoury, DO      03-15-2024
# 4     Ismael    Patino  Professional  Philip Khoury, DO      04-05-2024
#
#         Location Name Date Billed      Service Provided  \
# 0  SCOPES HEALTH INC.  04-23-2024  Initial Consultation
# 1  SCOPES HEALTH INC.  02-21-2024  Initial Consultation
# 2  SCOPES HEALTH INC.  04-30-2024   Injection Procedure
# 3  SCOPES HEALTH INC.  05-14-2024             Follow up
# 4  SCOPES HEALTH INC.  04-10-2024  Initial Consultation
#
#    Full Service Description                          Law Firm  \
# 0      Initial Consultation  Law Office of Young and  Nichols
# 1      Initial Consultation                 Drake Legal Group
# ...

# %%
#we need to recalculate the settlement Accepted Amount column in OpenCases data frame
OpenCases['Settlement Accepted'] = OpenCases['Item Charge'] - OpenCases['Item Charge'] * OpenCases['Lien Reduction %'] / 100
OpenCases['Discount Amount'] = OpenCases['Item Charge'] * OpenCases['Lien Reduction %'] / 100
OpenCases.head()
# Out:
#   First Name Last Name  Service Type      Physcian Name Date of Service  \
# 0    Katrina     Costa  Professional  Philip Khoury, DO      02-09-2024
# 1     Denise    Norris  Professional  Philip Khoury, DO      02-16-2024
# 2    Katrina     Costa  Professional  Philip Khoury, DO      02-24-2024
# 3    Katrina     Costa  Professional  Philip Khoury, DO      03-15-2024
# 4     Ismael    Patino  Professional  Philip Khoury, DO      04-05-2024
#
#         Location Name Date Billed      Service Provided  \
# 0  SCOPES HEALTH INC.  04-23-2024  Initial Consultation
# 1  SCOPES HEALTH INC.  02-21-2024  Initial Consultation
# 2  SCOPES HEALTH INC.  04-30-2024   Injection Procedure
# 3  SCOPES HEALTH INC.  05-14-2024             Follow up
# 4  SCOPES HEALTH INC.  04-10-2024  Initial Consultation
#
#    Full Service Description                          Law Firm  \
# 0      Initial Consultation  Law Office of Young and  Nichols
# 1      Initial Consultation                 Drake Legal Group
# ...

# %%
OpenCases['Pmt Date'] = OpenCases['Pmt Date'].fillna(pd.NaT)
OpenCases['Discount Date'] = OpenCases['Discount Date'].fillna(pd.NaT)
OpenCases.head()
# Out:
#   First Name Last Name  Service Type      Physcian Name Date of Service  \
# 0    Katrina     Costa  Professional  Philip Khoury, DO      02-09-2024
# 1     Denise    Norris  Professional  Philip Khoury, DO      02-16-2024
# 2    Katrina     Costa  Professional  Philip Khoury, DO      02-24-2024
# 3    Katrina     Costa  Professional  Philip Khoury, DO      03-15-2024
# 4     Ismael    Patino  Professional  Philip Khoury, DO      04-05-2024
#
#         Location Name Date Billed      Service Provided  \
# 0  SCOPES HEALTH INC.  04-23-2024  Initial Consultation
# 1  SCOPES HEALTH INC.  02-21-2024  Initial Consultation
# 2  SCOPES HEALTH INC.  04-30-2024   Injection Procedure
# 3  SCOPES HEALTH INC.  05-14-2024             Follow up
# 4  SCOPES HEALTH INC.  04-10-2024  Initial Consultation
#
#    Full Service Description                          Law Firm  \
# 0      Initial Consultation  Law Office of Young and  Nichols
# 1      Initial Consultation                 Drake Legal Group
# ...

# %%
OpenCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                427 non-null    object
#  1   Last Name                 427 non-null    object
#  2   Service Type              427 non-null    object
#  3   Physcian Name             427 non-null    object
#  4   Date of Service           427 non-null    object
#  5   Location Name             427 non-null    object
#  6   Date Billed               427 non-null    object
#  7   Service Provided          427 non-null    object
#  8   Full Service Description  427 non-null    object
#  9   Law Firm                  427 non-null    object
#  10  Attorney                  427 non-null    object
#  11  Case Rep                  416 non-null    object
#  12  Item Charge               427 non-null    int64
# ...

# %% [markdown]
# # Paid Cases

# %%
# makre a data frame from  Transactions - Paid Case Report.csv
PaidCases = pd.read_csv('../DataBase/Transactions - Paid Case Report.csv')
PaidCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                46 non-null     object
#  1   Last Name                 46 non-null     object
#  2   Service Type              46 non-null     object
#  3   Physcian Name             46 non-null     object
#  4   Date of Service           46 non-null     object
#  5   Date Billed               46 non-null     object
#  6   Service Provided          46 non-null     object
#  7   Full Service Description  46 non-null     object
#  8   Charge Amount             46 non-null     int64
#  9   Settlement Accepted       46 non-null     float64
#  10  Settlement %              46 non-null     object
#  11  Paid Amount               46 non-null     float64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
def clean_percentage(value):
    # Remove $, commas, %, then convert to float
    try:
        return float(value.replace("$", "").replace(",", "").replace("%", "").strip()) * 100
    except:
        return None  # handles blanks or bad values safely

# Apply function
PaidCases['Settlement %'] = PaidCases['Settlement %'].apply(clean_percentage)

PaidCases.head()
# Out:
#   First Name          Last Name  Service Type      Physcian Name  \
# 0     Sharaf                Ali  Professional  Philip Khoury, DO
# 1      Mayra  Angeles Rodriguez  Professional  Philip Khoury, DO
# 2   Melaynie              Armas  Professional  Philip Khoury, DO
# 3    Ernesto              Borja  Professional  Philip Khoury, DO
# 4    Ernesto              Borja  Professional  Philip Khoury, DO
#
#   Date of Service Date Billed      Service Provided Full Service Description  \
# 0      04/12/2024  04/18/2024  Initial Consultation     Initial Consultation
# 1      06/21/2024  07/01/2024  Initial Consultation     Initial Consultation
# 2      03/29/2024  04/09/2024  Initial Consultation     Initial Consultation
# 3      11/22/2024  11/26/2024  Initial Consultation     Initial Consultation
# 4      01/03/2025  01/09/2025             Follow up   Follow Up Consultation
#
#    Charge Amount  Settlement Accepted  Settlement %  Paid Amount    Pmt Date  \
# ...

# %%
PaidCases['Discount Amount'] = PaidCases['Charge Amount'] - PaidCases['Charge Amount'] * PaidCases['Settlement %'] / 100
PaidCases.head()
# Out:
#   First Name          Last Name  Service Type      Physcian Name  \
# 0     Sharaf                Ali  Professional  Philip Khoury, DO
# 1      Mayra  Angeles Rodriguez  Professional  Philip Khoury, DO
# 2   Melaynie              Armas  Professional  Philip Khoury, DO
# 3    Ernesto              Borja  Professional  Philip Khoury, DO
# 4    Ernesto              Borja  Professional  Philip Khoury, DO
#
#   Date of Service Date Billed      Service Provided Full Service Description  \
# 0      04/12/2024  04/18/2024  Initial Consultation     Initial Consultation
# 1      06/21/2024  07/01/2024  Initial Consultation     Initial Consultation
# 2      03/29/2024  04/09/2024  Initial Consultation     Initial Consultation
# 3      11/22/2024  11/26/2024  Initial Consultation     Initial Consultation
# 4      01/03/2025  01/09/2025             Follow up   Follow Up Consultation
#
#    Charge Amount  Settlement Accepted  Settlement %  Paid Amount    Pmt Date  \
# ...

# %%
PaidCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                46 non-null     object
#  1   Last Name                 46 non-null     object
#  2   Service Type              46 non-null     object
#  3   Physcian Name             46 non-null     object
#  4   Date of Service           46 non-null     object
#  5   Date Billed               46 non-null     object
#  6   Service Provided          46 non-null     object
#  7   Full Service Description  46 non-null     object
#  8   Charge Amount             46 non-null     int64
#  9   Settlement Accepted       46 non-null     float64
#  10  Settlement %              46 non-null     float64
#  11  Paid Amount               46 non-null     float64
#  12  Pmt Date                  46 non-null     object
# ...

# %%
# make date of service, date billed and Pmt Date columns datetime type and if empty put NaT
date_columns = ['Date of Service', 'Date Billed', 'Pmt Date']
for col in date_columns:
    PaidCases[col] = pd.to_datetime(PaidCases[col], errors='coerce').dt.strftime("%m-%d-%Y")
PaidCases.head()
# Out:
#   First Name          Last Name  Service Type      Physcian Name  \
# 0     Sharaf                Ali  Professional  Philip Khoury, DO
# 1      Mayra  Angeles Rodriguez  Professional  Philip Khoury, DO
# 2   Melaynie              Armas  Professional  Philip Khoury, DO
# 3    Ernesto              Borja  Professional  Philip Khoury, DO
# 4    Ernesto              Borja  Professional  Philip Khoury, DO
#
#   Date of Service Date Billed      Service Provided Full Service Description  \
# 0      04-12-2024  04-18-2024  Initial Consultation     Initial Consultation
# 1      06-21-2024  07-01-2024  Initial Consultation     Initial Consultation
# 2      03-29-2024  04-09-2024  Initial Consultation     Initial Consultation
# 3      11-22-2024  11-26-2024  Initial Consultation     Initial Consultation
# 4      01-03-2025  01-09-2025             Follow up   Follow Up Consultation
#
#    Charge Amount  Settlement Accepted  Settlement %  Paid Amount    Pmt Date  \
# ...

# %%
PaidCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                46 non-null     object
#  1   Last Name                 46 non-null     object
#  2   Service Type              46 non-null     object
#  3   Physcian Name             46 non-null     object
#  4   Date of Service           46 non-null     object
#  5   Date Billed               46 non-null     object
#  6   Service Provided          46 non-null     object
#  7   Full Service Description  46 non-null     object
#  8   Charge Amount             46 non-null     int64
#  9   Settlement Accepted       46 non-null     float64
#  10  Settlement %              46 non-null     float64
#  11  Paid Amount               46 non-null     float64
#  12  Pmt Date                  46 non-null     object
# ...

# %% [markdown]
# # Settled Cases

# %%
# make a data frame from  Transactions - Settled Case Report.csv
SettledCases = pd.read_csv("../DataBase/Transactions - Settled Case Report.csv")
SettledCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                24 non-null     object
#  1   Last Name                 24 non-null     object
#  2   Service Type              24 non-null     object
#  3   Physcian Name             24 non-null     object
#  4   Date of Service           24 non-null     object
#  5   Date Billed               24 non-null     object
#  6   Full Service Description  24 non-null     object
#  7   Charge Amount             24 non-null     int64
#  8   Settlement Accepted       24 non-null     float64
#  9   Settlement Date           24 non-null     object
#  10  Law Firm                  24 non-null     object
#  11  Attorney                  24 non-null     object
#  12  Case Rep                  24 non-null     object
# dtypes: float64(1), int64(1), object(11)
# ...

# %%
# make date of service, date billed columns datetime type and if empty put NaT
date_columns = ['Date of Service', 'Date Billed']
for col in date_columns:
    SettledCases[col] = pd.to_datetime(SettledCases[col], errors='coerce').dt.strftime("%m-%d-%Y")
SettledCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                24 non-null     object
#  1   Last Name                 24 non-null     object
#  2   Service Type              24 non-null     object
#  3   Physcian Name             24 non-null     object
#  4   Date of Service           24 non-null     object
#  5   Date Billed               24 non-null     object
#  6   Full Service Description  24 non-null     object
#  7   Charge Amount             24 non-null     int64
#  8   Settlement Accepted       24 non-null     float64
#  9   Settlement Date           24 non-null     object
#  10  Law Firm                  24 non-null     object
#  11  Attorney                  24 non-null     object
#  12  Case Rep                  24 non-null     object
# dtypes: float64(1), int64(1), object(11)
# ...

# %%
SettledCases.head()
# Out:
#   First Name       Last Name  Service Type      Physcian Name Date of Service  \
# 0    Arianna  Tirado-Sauceda  Professional  Philip Khoury, DO      11-01-2024
# 1       Jose          Medina  Professional  Philip Khoury, DO      11-01-2024
# 2  Marcelino        Martinez  Professional  Philip Khoury, DO      11-22-2024
# 3  Marcelino        Martinez  Professional  Philip Khoury, DO      01-03-2025
# 4   Michelle          Taylor  Professional  Philip Khoury, DO      03-28-2025
#
#   Date Billed Full Service Description  Charge Amount  Settlement Accepted  \
# 0  11-06-2024     Initial Consultation           1725               950.00
# 1  11-06-2024     Initial Consultation           1725               750.00
# 2  11-27-2024     Initial Consultation           1725               810.00
# 3  01-08-2025   Follow Up Consultation            975               410.00
# 4  03-31-2025     Initial Consultation           1725               463.61
#
# ...

# %%
# make a new column "Case Status" in AllCases, OpenCases, PaidCases, SettledCases data frames and fill it with "All", "Open", "Paid", "Settled" respectively
AllCases['Case Status'] = 'All'
OpenCases['Case Status'] = 'Open'
PaidCases['Case Status'] = 'Paid'
SettledCases['Case Status'] = 'Settled'

# %%
AllCases.head()
# Out:
#   First Name Last Name  Service Type       Location Name      Physcian Name  \
# 0     Sharaf       Ali  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 1   Melaynie     Armas  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 2    Ignacio      Diaz  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 3      Mitra   Atabaki  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
# 4    Ernesto     Borja  Professional  SCOPES HEALTH INC.  Philip Khoury, DO
#
#   Date of Service Date Billed Full Service Description  \
# 0      04-12-2024  04-18-2024     Initial Consultation
# 1      03-29-2024  04-09-2024     Initial Consultation
# 2      06-21-2024  06-27-2024     Initial Consultation
# 3      07-26-2024  07-31-2024     Initial Consultation
# 4      11-22-2024  11-26-2024     Initial Consultation
#
#                                Law Firm                 Attorney  \
# 0      Law Office of Young and  Nichols      Michael Young, Esq.
# ...

# %%
OpenCases.head()
# Out:
#   First Name Last Name  Service Type      Physcian Name Date of Service  \
# 0    Katrina     Costa  Professional  Philip Khoury, DO      02-09-2024
# 1     Denise    Norris  Professional  Philip Khoury, DO      02-16-2024
# 2    Katrina     Costa  Professional  Philip Khoury, DO      02-24-2024
# 3    Katrina     Costa  Professional  Philip Khoury, DO      03-15-2024
# 4     Ismael    Patino  Professional  Philip Khoury, DO      04-05-2024
#
#         Location Name Date Billed      Service Provided  \
# 0  SCOPES HEALTH INC.  04-23-2024  Initial Consultation
# 1  SCOPES HEALTH INC.  02-21-2024  Initial Consultation
# 2  SCOPES HEALTH INC.  04-30-2024   Injection Procedure
# 3  SCOPES HEALTH INC.  05-14-2024             Follow up
# 4  SCOPES HEALTH INC.  04-10-2024  Initial Consultation
#
#    Full Service Description                          Law Firm  ...  \
# 0      Initial Consultation  Law Office of Young and  Nichols  ...
# ...

# %%
PaidCases.head()
# Out:
#   First Name          Last Name  Service Type      Physcian Name  \
# 0     Sharaf                Ali  Professional  Philip Khoury, DO
# 1      Mayra  Angeles Rodriguez  Professional  Philip Khoury, DO
# 2   Melaynie              Armas  Professional  Philip Khoury, DO
# 3    Ernesto              Borja  Professional  Philip Khoury, DO
# 4    Ernesto              Borja  Professional  Philip Khoury, DO
#
#   Date of Service Date Billed      Service Provided Full Service Description  \
# 0      04-12-2024  04-18-2024  Initial Consultation     Initial Consultation
# 1      06-21-2024  07-01-2024  Initial Consultation     Initial Consultation
# 2      03-29-2024  04-09-2024  Initial Consultation     Initial Consultation
# 3      11-22-2024  11-26-2024  Initial Consultation     Initial Consultation
# 4      01-03-2025  01-09-2025             Follow up   Follow Up Consultation
#
#    Charge Amount  Settlement Accepted  Settlement %  Paid Amount    Pmt Date  \
# ...

# %%
SettledCases.head()
# Out:
#   First Name       Last Name  Service Type      Physcian Name Date of Service  \
# 0    Arianna  Tirado-Sauceda  Professional  Philip Khoury, DO      11-01-2024
# 1       Jose          Medina  Professional  Philip Khoury, DO      11-01-2024
# 2  Marcelino        Martinez  Professional  Philip Khoury, DO      11-22-2024
# 3  Marcelino        Martinez  Professional  Philip Khoury, DO      01-03-2025
# 4   Michelle          Taylor  Professional  Philip Khoury, DO      03-28-2025
#
#   Date Billed Full Service Description  Charge Amount  Settlement Accepted  \
# 0  11-06-2024     Initial Consultation           1725               950.00
# 1  11-06-2024     Initial Consultation           1725               750.00
# 2  11-27-2024     Initial Consultation           1725               810.00
# 3  01-08-2025   Follow Up Consultation            975               410.00
# 4  03-31-2025     Initial Consultation           1725               463.61
#
# ...

# %%
# i want .info() of OpenCases, PaidCases, SettledCases data frames
print("OpenCases info:")
OpenCases.info()
print("PaidCases info:")
PaidCases.info()
print("SettledCases info:")
SettledCases.info()
# Out:
# OpenCases info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                427 non-null    object
#  1   Last Name                 427 non-null    object
#  2   Service Type              427 non-null    object
#  3   Physcian Name             427 non-null    object
#  4   Date of Service           427 non-null    object
#  5   Location Name             427 non-null    object
#  6   Date Billed               427 non-null    object
#  7   Service Provided          427 non-null    object
#  8   Full Service Description  427 non-null    object
#  9   Law Firm                  427 non-null    object
#  10  Attorney                  427 non-null    object
#  11  Case Rep                  416 non-null    object
#  12  Item Charge               427 non-null    int64
# ...

# %%
#stack OpenCases, PaidCases, SettledCases data frames on top of each other
CombinedCases = pd.concat([OpenCases, PaidCases, SettledCases], ignore_index=True)
print("CombinedCases info:")
CombinedCases.info()
# Out:
# CombinedCases info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                497 non-null    object
#  1   Last Name                 497 non-null    object
#  2   Service Type              497 non-null    object
#  3   Physcian Name             497 non-null    object
#  4   Date of Service           497 non-null    object
#  5   Location Name             427 non-null    object
#  6   Date Billed               497 non-null    object
#  7   Service Provided          473 non-null    object
#  8   Full Service Description  497 non-null    object
#  9   Law Firm                  497 non-null    object
#  10  Attorney                  497 non-null    object
#  11  Case Rep                  486 non-null    object
#  12  Item Charge               427 non-null    float64
# ...

# %%
print(OpenCases['Location Name'].unique())
# Out:
# ['SCOPES HEALTH INC.' 'UNIVERSITY SURGICAL INSTITUTE, LLC'
#  'ANESTHESIOLOGY & PERIOPERATIVE MEDICINE SPECIALISTS']

# %%
print(AllCases['Service Type'].unique())
# Out:
# ['Professional' 'Facility' 'Anesthesia']

# %%
#make a new column depeneds on a condition in CombinedCases data frame if Service Type is "Professional" then "SCOPES HEALTH INC." else if "Anesthesia" then "ANESTHESIOLOGY & PERIOPERATIVE MEDICINE SPECIALISTS" else if "Facility" then "UNIVERSITY SURGICAL INSTITUTE, LLC" and name it "ENTITY"
CombinedCases['Entity'] = CombinedCases['Service Type'].apply(lambda x: "SCOPES HEALTH INC." if x == "Professional" else "ANESTHESIOLOGY & PERIOPERATIVE MEDICINE SPECIALISTS" if x == "Anesthesia" else "UNIVERSITY SURGICAL INSTITUTE, LLC" if x == "Facility" else "")
CombinedCases.head()
# Out:
#   First Name Last Name  Service Type      Physcian Name Date of Service  \
# 0    Katrina     Costa  Professional  Philip Khoury, DO      02-09-2024
# 1     Denise    Norris  Professional  Philip Khoury, DO      02-16-2024
# 2    Katrina     Costa  Professional  Philip Khoury, DO      02-24-2024
# 3    Katrina     Costa  Professional  Philip Khoury, DO      03-15-2024
# 4     Ismael    Patino  Professional  Philip Khoury, DO      04-05-2024
#
#         Location Name Date Billed      Service Provided  \
# 0  SCOPES HEALTH INC.  04-23-2024  Initial Consultation
# 1  SCOPES HEALTH INC.  02-21-2024  Initial Consultation
# 2  SCOPES HEALTH INC.  04-30-2024   Injection Procedure
# 3  SCOPES HEALTH INC.  05-14-2024             Follow up
# 4  SCOPES HEALTH INC.  04-10-2024  Initial Consultation
#
#    Full Service Description                          Law Firm  ...  \
# 0      Initial Consultation  Law Office of Young and  Nichols  ...
# ...

# %%
#show me both columns "Service Type" and "ENTITY" unique values in CombinedCases data frame
CombinedCases[['Service Type', 'Entity']].drop_duplicates()
# Out:
#    Service Type                                             Entity
# 0  Professional                                 SCOPES HEALTH INC.
# 8      Facility                 UNIVERSITY SURGICAL INSTITUTE, LLC
# 9    Anesthesia  ANESTHESIOLOGY & PERIOPERATIVE MEDICINE SPECIA...

# %%
#check for anyduplicates in CombinedCases data frame and output the rows duplicated i want both rows
CombinedCases[CombinedCases.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Service Type, Physcian Name, Date of Service, Location Name, Date Billed, Service Provided, Full Service Description, Law Firm, Attorney, Case Rep, Item Charge, Pmt Date, Paid Amount, Collection %, Lien Reduction %, Settlement Accepted, Discount Date, Discount Amount, Case Status, Charge Amount, Settlement %, Settlement Date, Entity]
# Index: []
#
# [0 rows x 25 columns]

# %%
#drop duplicates in CombinedCases data frame and keep the first occurrence
CombinedCases = CombinedCases.drop_duplicates(keep='first')
CombinedCases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   First Name                497 non-null    object
#  1   Last Name                 497 non-null    object
#  2   Service Type              497 non-null    object
#  3   Physcian Name             497 non-null    object
#  4   Date of Service           497 non-null    object
#  5   Location Name             427 non-null    object
#  6   Date Billed               497 non-null    object
#  7   Service Provided          473 non-null    object
#  8   Full Service Description  497 non-null    object
#  9   Law Firm                  497 non-null    object
#  10  Attorney                  497 non-null    object
#  11  Case Rep                  486 non-null    object
#  12  Item Charge               427 non-null    float64
# ...

# %%
# Save CombinedCases DataFrame to an Excel file in the "../DatBase/" directory
CombinedCases.to_excel("../DataBase/CombinedCasesFinal.xlsx", index=False)
